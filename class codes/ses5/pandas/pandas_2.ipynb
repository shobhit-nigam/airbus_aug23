# %%
import pandas as pd
import numpy as np

# %%
dfa = pd.read_csv("one.csv")

# %%
dict_x = {"aa":20, "tt":40, "ww":32, "gt":90}
sa = pd.Series(dict_x)

# %%
dict_x = {"aa":20, "tt":40, "ww":32, "gt":90}

sb = pd.Series(dict_x, index = ["aa", "bb", "tt", "ww", "gt"])

# %%
sd = pd.Series(np.random.randn(6), name="random_data")

# %%
dict_y = {"xxx":[10, 20, 30, 40], "yyy":[76, 65, 54, 43], "zzz":[10, 94, 65, 20]}

# %%
dfb = pd.DataFrame(dict_y)

# %%
list_a = [{"aa":20, "ff":30}, {"aa":10, "ff":40}, {"aa":10, "ff":30, "rr":56}]

dfc = pd.DataFrame(list_a)

# %%
dfb.columns = ["first", "second", "third"]
dfb["fourth"] = [5, 8, 9, 10]
dfb["fifth"] = dfb["second"] - dfb["third"]
dfb["sixth"] = dfb["third"] > 50

# %%
# del dfb["fifth"]

x = dfb.pop("fifth")

# %%
dfb["fifth"] = "monday"

# %%
dfe = dfb.copy()

# %%
dfe.index = ["q", "w", "e", "r"]

# %%
dfb
# Out:
#    first  second  third  fourth  sixth   fifth
# 0     10      76     10       5  False  monday
# 1     20      65     94       8   True  monday
# 2     30      54     65       9   True  monday
# 3     40      43     20      10  False  monday

# %%
dfb.max()
# Out:
# first         40
# second        76
# third         94
# fourth        10
# sixth       True
# fifth     monday
# dtype: object

# %%
dfb["third"].max()
# Out:
# 94

# %%
dfb.describe()
# Out:
#            first     second      third     fourth
# count   4.000000   4.000000   4.000000   4.000000
# mean   25.000000  59.500000  47.250000   8.000000
# std    12.909944  14.200939  39.288463   2.160247
# min    10.000000  43.000000  10.000000   5.000000
# 25%    17.500000  51.250000  17.500000   7.250000
# 50%    25.000000  59.500000  42.500000   8.500000
# 75%    32.500000  67.750000  72.250000   9.250000
# max    40.000000  76.000000  94.000000  10.000000

# %%
dfc
# Out:
#    aa  ff    rr
# 0  20  30   NaN
# 1  10  40   NaN
# 2  10  30  56.0

# %%
dfc.isna()
# Out:
#       aa     ff     rr
# 0  False  False   True
# 1  False  False   True
# 2  False  False  False

# %%
dfc.isna().sum()
# Out:
# aa    0
# ff    0
# rr    2
# dtype: int64

# %%
dfa
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
dfb.any()
# Out:
# first     True
# second    True
# third     True
# fourth    True
# sixth     True
# fifth     True
# dtype: bool

# %%
dfc.all()
# Out:
# aa    True
# ff    True
# rr    True
# dtype: bool

# %%
dfb.all()
# Out:
# first      True
# second     True
# third      True
# fourth     True
# sixth     False
# fifth      True
# dtype: bool

# %%
dfb
# Out:
#    first  second  third  fourth  sixth   fifth
# 0     10      76     10       5  False  monday
# 1     20      65     94       8   True  monday
# 2     30      54     65       9   True  monday
# 3     40      43     20      10  False  monday

# %%
dfb["third"].idxmax()
# Out:
# 1

# %%
dfb["second"].idxmin()
# Out:
# 3

# %%
dfd = dfb.copy()

# %%
dfd
# Out:
#    first  second  third  fourth  sixth   fifth
# 0     10      76     10       5  False  monday
# 1     20      65     94       8   True  monday
# 2     30      54     65       9   True  monday
# 3     40      43     20      10  False  monday

# %%
del dfd["sixth"]
del dfd["fifth"]

# %%
dfd
# Out:
#    first  second  third  fourth
# 0     10      76     10       5
# 1     20      65     94       8
# 2     30      54     65       9
# 3     40      43     20      10

# %%
dfd.apply(np.exp)
# Out:
#           first        second         third        fourth
# 0  2.202647e+04  1.014800e+33  2.202647e+04    148.413159
# 1  4.851652e+08  1.694889e+28  6.663176e+40   2980.957987
# 2  1.068647e+13  2.830753e+23  1.694889e+28   8103.083928
# 3  2.353853e+17  4.727839e+18  4.851652e+08  22026.465795

# %%
dfd["first"].apply("mean")
# Out:
# 25.0

# %%
dfd.apply(lambda x: x.max() - x.min())
# Out:
# first     30
# second    33
# third     84
# fourth     5
# dtype: int64

# %%
dfd
# Out:
#    first  second  third  fourth
# 0     10      76     10       5
# 1     20      65     94       8
# 2     30      54     65       9
# 3     40      43     20      10

# %%
dfd.agg(["sum"])
# Out:
#      first  second  third  fourth
# sum    100     238    189      32

# %%
type(dfd.agg(["sum"]))
# Out:
# pandas.core.frame.DataFrame

# %%
dfd
# Out:
#    first  second  third  fourth
# 0     10      76     10       5
# 1     20      65     94       8
# 2     30      54     65       9
# 3     40      43     20      10

# %%
dfd.describe()
# Out:
#            first     second      third     fourth
# count   4.000000   4.000000   4.000000   4.000000
# mean   25.000000  59.500000  47.250000   8.000000
# std    12.909944  14.200939  39.288463   2.160247
# min    10.000000  43.000000  10.000000   5.000000
# 25%    17.500000  51.250000  17.500000   7.250000
# 50%    25.000000  59.500000  42.500000   8.500000
# 75%    32.500000  67.750000  72.250000   9.250000
# max    40.000000  76.000000  94.000000  10.000000

# %%
dfd_desc = dfd.agg(["sum"])

# %%
dfd_desc
# Out:
#      first  second  third  fourth
# sum    100     238    189      32

# %%
dfd_desc = dfd.agg(["sum", "mean"])

# %%
dfd_desc
# Out:
#       first  second   third  fourth
# sum   100.0   238.0  189.00    32.0
# mean   25.0    59.5   47.25     8.0

# %%
def cal_gst_ser(x):
    return x*1.18 + 10

# %%
def cal_gst_ser(x):
    return x*1.18 + 10

# %%
dfd.applymap(cal_gst_ser)
# Out:
#    first  second   third  fourth
# 0   21.8   99.68   21.80   15.90
# 1   33.6   86.70  120.92   19.44
# 2   45.4   73.72   86.70   20.62
# 3   57.2   60.74   33.60   21.80

# %%
dfe = pd.read_excel("info_data.xlsx", sheet_name="tue")

# %%
dfe
# Out:
#     info    val  data
# 0  235.0   43.0   100
# 1  267.5   74.0    30
# 2  300.0   87.2    84
# 3  332.5  100.4    93
# 4  365.0  113.6    25
# 5  397.5  126.8    54
# 6  430.0  140.0   109

# %%
objx = pd.ExcelFile("info_data.xlsx")

# %%
type(objx)
# Out:
# pandas.io.excel._base.ExcelFile

# %%
objx.sheet_names
# Out:
# ['mon', 'tue']

# %%
dff = objx.parse(objx.sheet_names[0])

# %%
dff
# Out:
#      info  Unnamed: 1   data
# 0    11.0        12.0   23.0
# 1    33.0        45.0   45.0
# 2    76.0        98.0   67.0
# 3   105.0        12.0   12.0
# 4   137.5         7.0    NaN
# 5   170.0        45.0   89.0
# 6   202.5        69.0   32.0
# 7   235.0        43.0  100.0
# 8   267.5        74.0    NaN
# 9   300.0        87.2   84.0
# 10  332.5       100.4   93.0
# 11  365.0       113.6   25.0
# 12  397.5       126.8    NaN
# 13  430.0       140.0  109.0

# %%
dfg = pd.read_excel("info_data.xlsx", objx.sheet_names[1])

# %%
dfg
# Out:
#     info    val  data
# 0  235.0   43.0   100
# 1  267.5   74.0    30
# 2  300.0   87.2    84
# 3  332.5  100.4    93
# 4  365.0  113.6    25
# 5  397.5  126.8    54
# 6  430.0  140.0   109

# %%
dfg
# Out:
#     info    val  data
# 0  235.0   43.0   100
# 1  267.5   74.0    30
# 2  300.0   87.2    84
# 3  332.5  100.4    93
# 4  365.0  113.6    25
# 5  397.5  126.8    54
# 6  430.0  140.0   109

# %%
dff
# Out:
#      info  Unnamed: 1   data
# 0    11.0        12.0   23.0
# 1    33.0        45.0   45.0
# 2    76.0        98.0   67.0
# 3   105.0        12.0   12.0
# 4   137.5         7.0    NaN
# 5   170.0        45.0   89.0
# 6   202.5        69.0   32.0
# 7   235.0        43.0  100.0
# 8   267.5        74.0    NaN
# 9   300.0        87.2   84.0
# 10  332.5       100.4   93.0
# 11  365.0       113.6   25.0
# 12  397.5       126.8    NaN
# 13  430.0       140.0  109.0

# %%
dff.isna().sum()
# Out:
# info          0
# Unnamed: 1    0
# data          3
# dtype: int64

# %%
dfh = dff.copy()
dff['data'].fillna(61)
# Out:
# 0      23.0
# 1      45.0
# 2      67.0
# 3      12.0
# 4      61.0
# 5      89.0
# 6      32.0
# 7     100.0
# 8      61.0
# 9      84.0
# 10     93.0
# 11     25.0
# 12     61.0
# 13    109.0
# Name: data, dtype: float64

# %%
dff
# Out:
#      info  Unnamed: 1   data
# 0    11.0        12.0   23.0
# 1    33.0        45.0   45.0
# 2    76.0        98.0   67.0
# 3   105.0        12.0   12.0
# 4   137.5         7.0    NaN
# 5   170.0        45.0   89.0
# 6   202.5        69.0   32.0
# 7   235.0        43.0  100.0
# 8   267.5        74.0    NaN
# 9   300.0        87.2   84.0
# 10  332.5       100.4   93.0
# 11  365.0       113.6   25.0
# 12  397.5       126.8    NaN
# 13  430.0       140.0  109.0

# %%
dff['data'] = dff['data'].fillna(61)

# %%
dff
# Out:
#      info  Unnamed: 1   data
# 0    11.0        12.0   23.0
# 1    33.0        45.0   45.0
# 2    76.0        98.0   67.0
# 3   105.0        12.0   12.0
# 4   137.5         7.0   61.0
# 5   170.0        45.0   89.0
# 6   202.5        69.0   32.0
# 7   235.0        43.0  100.0
# 8   267.5        74.0   61.0
# 9   300.0        87.2   84.0
# 10  332.5       100.4   93.0
# 11  365.0       113.6   25.0
# 12  397.5       126.8   61.0
# 13  430.0       140.0  109.0

# %%
dff.sort_values(["data"])
# Out:
#      info  Unnamed: 1   data
# 3   105.0        12.0   12.0
# 0    11.0        12.0   23.0
# 11  365.0       113.6   25.0
# 6   202.5        69.0   32.0
# 1    33.0        45.0   45.0
# 4   137.5         7.0   61.0
# 8   267.5        74.0   61.0
# 12  397.5       126.8   61.0
# 2    76.0        98.0   67.0
# 9   300.0        87.2   84.0
# 5   170.0        45.0   89.0
# 10  332.5       100.4   93.0
# 7   235.0        43.0  100.0
# 13  430.0       140.0  109.0

# %%
dff
# Out:
#      info  Unnamed: 1   data
# 0    11.0        12.0   23.0
# 1    33.0        45.0   45.0
# 2    76.0        98.0   67.0
# 3   105.0        12.0   12.0
# 4   137.5         7.0   61.0
# 5   170.0        45.0   89.0
# 6   202.5        69.0   32.0
# 7   235.0        43.0  100.0
# 8   267.5        74.0   61.0
# 9   300.0        87.2   84.0
# 10  332.5       100.4   93.0
# 11  365.0       113.6   25.0
# 12  397.5       126.8   61.0
# 13  430.0       140.0  109.0

# %%
dff.sort_values(["data"], inplace=True)

# %%
dff
# Out:
#      info  Unnamed: 1   data
# 3   105.0        12.0   12.0
# 0    11.0        12.0   23.0
# 11  365.0       113.6   25.0
# 6   202.5        69.0   32.0
# 1    33.0        45.0   45.0
# 4   137.5         7.0   61.0
# 8   267.5        74.0   61.0
# 12  397.5       126.8   61.0
# 2    76.0        98.0   67.0
# 9   300.0        87.2   84.0
# 5   170.0        45.0   89.0
# 10  332.5       100.4   93.0
# 7   235.0        43.0  100.0
# 13  430.0       140.0  109.0

# %%
dff.reindex(np.arange(14))
# Out:
#      info  Unnamed: 1   data
# 0    11.0        12.0   23.0
# 1    33.0        45.0   45.0
# 2    76.0        98.0   67.0
# 3   105.0        12.0   12.0
# 4   137.5         7.0   61.0
# 5   170.0        45.0   89.0
# 6   202.5        69.0   32.0
# 7   235.0        43.0  100.0
# 8   267.5        74.0   61.0
# 9   300.0        87.2   84.0
# 10  332.5       100.4   93.0
# 11  365.0       113.6   25.0
# 12  397.5       126.8   61.0
# 13  430.0       140.0  109.0

# %%
dff
# Out:
#      info  Unnamed: 1   data
# 3   105.0        12.0   12.0
# 0    11.0        12.0   23.0
# 11  365.0       113.6   25.0
# 6   202.5        69.0   32.0
# 1    33.0        45.0   45.0
# 4   137.5         7.0   61.0
# 8   267.5        74.0   61.0
# 12  397.5       126.8   61.0
# 2    76.0        98.0   67.0
# 9   300.0        87.2   84.0
# 5   170.0        45.0   89.0
# 10  332.5       100.4   93.0
# 7   235.0        43.0  100.0
# 13  430.0       140.0  109.0

# %%
dff.rename(columns={"Unnamed: 1":"values"}, inplace=True)

# %%
dff
# Out:
#      info  values   data
# 3   105.0    12.0   12.0
# 0    11.0    12.0   23.0
# 11  365.0   113.6   25.0
# 6   202.5    69.0   32.0
# 1    33.0    45.0   45.0
# 4   137.5     7.0   61.0
# 8   267.5    74.0   61.0
# 12  397.5   126.8   61.0
# 2    76.0    98.0   67.0
# 9   300.0    87.2   84.0
# 5   170.0    45.0   89.0
# 10  332.5   100.4   93.0
# 7   235.0    43.0  100.0
# 13  430.0   140.0  109.0

# %%
dff [ (dff["values"] > 70) & (dff["data"] < 80) ]
# Out:
#      info  values  data
# 11  365.0   113.6  25.0
# 8   267.5    74.0  61.0
# 12  397.5   126.8  61.0
# 2    76.0    98.0  67.0

# %%
dff.index = np.arange(14)

# %%
dff
# Out:
#      info  values   data
# 0   105.0    12.0   12.0
# 1    11.0    12.0   23.0
# 2   365.0   113.6   25.0
# 3   202.5    69.0   32.0
# 4    33.0    45.0   45.0
# 5   137.5     7.0   61.0
# 6   267.5    74.0   61.0
# 7   397.5   126.8   61.0
# 8    76.0    98.0   67.0
# 9   300.0    87.2   84.0
# 10  170.0    45.0   89.0
# 11  332.5   100.4   93.0
# 12  235.0    43.0  100.0
# 13  430.0   140.0  109.0
